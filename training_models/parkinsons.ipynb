# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score,precision_score,recall_score

# %%
parkinson_dataset = pd.read_csv("../datasets/parkinsons.csv")

# %%
parkinson_dataset.shape
# Out:
# (195, 24)

# %%
parkinson_dataset.head()
#from this data I can clearly say that the status is dependent y  and other is independent as x
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302  ...  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650  ...  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111  ...  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871  ...  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781  ...  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
parkinson_dataset.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...          D2         PPE
# count   195.000000    195.000000  ...  195.000000  195.000000
# mean    154.228641    197.104918  ...    2.381826    0.206552
# std      41.390065     91.491548  ...    0.382799    0.090119
# min      88.333000    102.145000  ...    1.423287    0.044539
# 25%     117.572000    134.862500  ...    2.099125    0.137451
# 50%     148.790000    175.829000  ...    2.361532    0.194052
# 75%     182.769000    224.205500  ...    2.636456    0.252980
# max     260.105000    592.030000  ...    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
parkinson_dataset['status'].value_counts()
#how to balance data - tomexlink
#confusion matrix
#medium articles
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
X= parkinson_dataset.drop(columns=['status','name'],axis=1)
Y = parkinson_dataset['status']

# %%
X.shape
# Out:
# (195, 22)

# %%
Y.shape
# Out:
# (195,)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
Y_pred = model.predict(X_test)

# %%
print(accuracy_score(Y_test,Y_pred))
print(precision_score(Y_test,Y_pred))
print(recall_score(Y_test,Y_pred))
# Out:
# 0.8717948717948718
# 0.8857142857142857
# 0.96875

# %%
import pickle
fileName = "parkinsons_model.sav"
pickle.dump(model,open(fileName,'wb'))
